# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_excel('GastosYcostos20-30.xlsx', sheet_name='2022')
data
# Out:
#           Fecha         Folio                                  UUID  \
# 0    2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1    2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2    2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3    2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4    2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...         ...           ...                                   ...
# 2572 2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573 2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574 2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575 2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576 2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 1      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 2      BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 3     ZEGC530520V4A                   CARLOS ENRIQUE ZERMEÑO GUTIERREZ
# 4     ZEGC530520V4A                   CARLOS ENRIQUE ZERMEÑO GUTIERREZ
# ...             ...                                                ...
# 2572   BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 2573   BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 2574   AAE6411055P8               Aesa Articulos Electricos S.A de C.V
# 2575   AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 2576   AAE6411055P8                          AESA ARTICULOS ELECTRICOS
#
#                     TIPO GASTO  \
# 0     ARRENDAMIENTO FINANCIERO
# 1     ARRENDAMIENTO FINANCIERO
# 2            COMISION BANCARIA
# 3                      COMPRAS
# 4                      COMPRAS
# ...                        ...
# 2572         COMISION BANCARIA
# 2573         COMISION BANCARIA
# 2574                   COMPRAS
# 2575                   COMPRAS
# 2576                   COMPRAS
#
#                                             Descripción   MP   TC   Importe  \
# 0     AA RENTA EXIGIBLE CL0000006876 18/36 de 03/12/...  PPD  1.0   5551.38
# 1     AA RENTA EXIGIBLE CL0000006877 18/36 de 03/12/...  PPD  1.0   5551.98
# 2                              Servicios de Facturación  PUE  1.0      0.00
# 3                                                  Pago  NaN  1.0      0.00
# 4                                                  Pago  NaN  1.0      0.00
# ...                                                 ...  ...  ...       ...
# 2572                             COMISIONES E INTERESES  PUE  1.0      0.00
# 2573                                SERVICIOS BANCARIOS  PUE  1.0  17310.30
# 2574                                               Pago  NaN  NaN      0.00
# 2575                                               Pago  NaN  NaN      0.00
# 2576                                               Pago  NaN  NaN      0.00
#
#          IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo   Status  \
# 0     888.22      0.0      0.0    NaN   6439.60    6439.60    I  Vigente
# 1     888.32      0.0      0.0    NaN   6440.30    6440.30    I  Vigente
# 2       0.00      0.0      0.0    NaN      0.00       0.00    I  Vigente
# 3       0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# 4       0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# ...      ...      ...      ...    ...       ...        ...  ...      ...
# 2572    0.00      0.0      0.0    NaN      0.00       0.00    I  Vigente
# 2573  516.32      0.0      0.0    NaN  17826.62   17826.62    I  Vigente
# 2574    0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# 2575    0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# 2576    0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
#
#           Poliza
# 0     PE02-ENE22
# 1     PE03-ENE22
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2572         NaN
# 2573         NaN
# 2574         NaN
# 2575         NaN
# 2576         NaN
#
# [2577 rows x 19 columns]

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Fecha             0
# Folio           102
# UUID              0
# RFC               0
# Proveedor         0
# TIPO GASTO        0
# Descripción       0
# MP              553
# TC              636
# Importe           0
# IVA               0
# RET ISR           0
# RET IVA           0
# Otros          2577
# TOTAL MX          0
# TOTAL SAT         0
# Tipo              0
# Status            0
# Poliza          801
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#           Fecha         Folio                                  UUID  \
# 0    2022-01-01        280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1    2022-01-01        280109  7E00E776-A839-4D57-B291-411109164B2F
# 2    2022-01-01  007817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3    2022-01-01          5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4    2022-01-01          5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...         ...           ...                                   ...
# 2572 2022-12-01        863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573 2022-12-01    1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574 2022-12-01             4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575 2022-12-01            16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576 2022-12-01            17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 1      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 2      BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# 3     ZEGC530520V4A                   CARLOS ENRIQUE ZERMEÑO GUTIERREZ
# 4     ZEGC530520V4A                   CARLOS ENRIQUE ZERMEÑO GUTIERREZ
# ...             ...                                                ...
# 2572   BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 2573   BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 2574   AAE6411055P8               Aesa Articulos Electricos S.A de C.V
# 2575   AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 2576   AAE6411055P8                          AESA ARTICULOS ELECTRICOS
#
#                     TIPO GASTO  \
# 0     ARRENDAMIENTO FINANCIERO
# 1     ARRENDAMIENTO FINANCIERO
# 2            COMISION BANCARIA
# 3                      COMPRAS
# 4                      COMPRAS
# ...                        ...
# 2572         COMISION BANCARIA
# 2573         COMISION BANCARIA
# 2574                   COMPRAS
# 2575                   COMPRAS
# 2576                   COMPRAS
#
#                                             Descripción   MP   TC   Importe  \
# 0     AA RENTA EXIGIBLE CL0000006876 18/36 de 03/12/...  PPD  1.0   5551.38
# 1     AA RENTA EXIGIBLE CL0000006877 18/36 de 03/12/...  PPD  1.0   5551.98
# 2                              Servicios de Facturación  PUE  1.0      0.00
# 3                                                  Pago  PUE  1.0      0.00
# 4                                                  Pago  PUE  1.0      0.00
# ...                                                 ...  ...  ...       ...
# 2572                             COMISIONES E INTERESES  PUE  1.0      0.00
# 2573                                SERVICIOS BANCARIOS  PUE  1.0  17310.30
# 2574                                               Pago  NaN  NaN      0.00
# 2575                                               Pago  NaN  NaN      0.00
# 2576                                               Pago  NaN  NaN      0.00
#
#          IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo   Status  \
# 0     888.22      0.0      0.0    NaN   6439.60    6439.60    I  Vigente
# 1     888.32      0.0      0.0    NaN   6440.30    6440.30    I  Vigente
# 2       0.00      0.0      0.0    NaN      0.00       0.00    I  Vigente
# 3       0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# 4       0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# ...      ...      ...      ...    ...       ...        ...  ...      ...
# 2572    0.00      0.0      0.0    NaN      0.00       0.00    I  Vigente
# 2573  516.32      0.0      0.0    NaN  17826.62   17826.62    I  Vigente
# 2574    0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# 2575    0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
# 2576    0.00      0.0      0.0    NaN      0.00       0.00    P  Vigente
#
#           Poliza
# 0     PE02-ENE22
# 1     PE03-ENE22
# 2     PE01-ENE22
# 3     PE01-ENE22
# 4     PE01-ENE22
# ...          ...
# 2572         NaN
# 2573         NaN
# 2574         NaN
# 2575         NaN
# 2576         NaN
#
# [2577 rows x 19 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Fecha             0
# Folio             0
# UUID              0
# RFC               0
# Proveedor         0
# TIPO GASTO        0
# Descripción       0
# MP                3
# TC                3
# Importe           0
# IVA               0
# RET ISR           0
# RET IVA           0
# Otros          2577
# TOTAL MX          0
# TOTAL SAT         0
# Tipo              0
# Status            0
# Poliza           12
# dtype: int64

# %%
data2=data.copy()

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido Fecha                 NaT
# IVA           5048.646001
# Importe      34975.501132
# Otros                 NaN
# RET ISR        977.619941
# RET IVA       1046.847384
# TC               6.710471
# TOTAL MX     39054.094273
# TOTAL SAT    39095.543969
# dtype: object
# Limite inferior permitido Fecha                 NaT
# IVA          -4069.819702
# Importe     -26990.441616
# Otros                 NaN
# RET ISR       -902.558225
# RET IVA       -964.592475
# TC              -4.353819
# TOTAL MX    -30247.525081
# TOTAL SAT   -30172.959879
# dtype: object
# <ipython-input-8-4c899ed993c2>:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-8-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-8-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-8-4c899ed993c2>:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-8-4c899ed993c2>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-8-4c899ed993c2>:4: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-9-b3686d19c4d6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
#      Fecha Folio UUID  RFC Proveedor TIPO GASTO Descripción   MP  TC  Importe  \
# 0      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 1      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 2      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 3      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 4      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# ...    ...   ...  ...  ...       ...        ...         ...  ...  ..      ...
# 2572   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 2573   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 2574   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 2575   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
# 2576   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN      NaN
#
#       IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo Status Poliza
# 0     NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 1     NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 2     NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 3     NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 4     NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# ...   ...      ...      ...    ...       ...        ...  ...    ...    ...
# 2572  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 2573  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 2574  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 2575  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
# 2576  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN    NaN
#
# [2577 rows x 19 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-10-1e038dbc0c4a>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#      Fecha Folio UUID  RFC Proveedor TIPO GASTO Descripción   MP   TC  \
# 0      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  1.0
# 1      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  1.0
# 2      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  1.0
# 3      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  1.0
# 4      NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  1.0
# ...    ...   ...  ...  ...       ...        ...         ...  ...  ...
# 2572   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  1.0
# 2573   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  1.0
# 2574   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  NaN
# 2575   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  NaN
# 2576   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  NaN
#
#        Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo  \
# 0      5551.38  888.22      0.0      0.0    NaN   6439.60    6439.60  NaN
# 1      5551.98  888.32      0.0      0.0    NaN   6440.30    6440.30  NaN
# 2         0.00    0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 3         0.00    0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 4         0.00    0.00      0.0      0.0    NaN      0.00       0.00  NaN
# ...        ...     ...      ...      ...    ...       ...        ...  ...
# 2572      0.00    0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 2573  17310.30  516.32      0.0      0.0    NaN  17826.62   17826.62  NaN
# 2574      0.00    0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 2575      0.00    0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 2576      0.00    0.00      0.0      0.0    NaN      0.00       0.00  NaN
#
#      Status Poliza
# 0       NaN    NaN
# 1       NaN    NaN
# 2       NaN    NaN
# 3       NaN    NaN
# 4       NaN    NaN
# ...     ...    ...
# 2572    NaN    NaN
# 2573    NaN    NaN
# 2574    NaN    NaN
# 2575    NaN    NaN
# 2576    NaN    NaN
#
# [2577 rows x 19 columns]

# %%
#Eliminamos columnas innecesarias

data4=data3.iloc[ : , 8:15]  
data4
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0   5551.38  888.22      0.0      0.0    NaN   6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    NaN   6440.30
# 2     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 3     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 4     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# ...   ...       ...     ...      ...      ...    ...       ...
# 2572  1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    NaN  17826.62
# 2574  NaN      0.00    0.00      0.0      0.0    NaN      0.00
# 2575  NaN      0.00    0.00      0.0      0.0    NaN      0.00
# 2576  NaN      0.00    0.00      0.0      0.0    NaN      0.00
#
# [2577 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data4.isnull().sum()
valores_nulos
# Out:
# TC           654
# Importe       36
# IVA           31
# RET ISR       32
# RET IVA       32
# Otros       2577
# TOTAL MX      36
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data4.copy()
data_clean=data_clean.fillna(round(data4.mean(),1))
data_clean
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0   5551.38  888.22      0.0      0.0    NaN   6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    NaN   6440.30
# 2     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 3     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 4     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# ...   ...       ...     ...      ...      ...    ...       ...
# 2572  1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    NaN  17826.62
# 2574  1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 2575  1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 2576  1.0      0.00    0.00      0.0      0.0    NaN      0.00
#
# [2577 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# Otros       2577
# TOTAL MX       0
# dtype: int64

# %%
data2= data.iloc[ : , 8:15]
data2
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0   5551.38  888.22      0.0      0.0    NaN   6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    NaN   6440.30
# 2     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 3     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 4     1.0      0.00    0.00      0.0      0.0    NaN      0.00
# ...   ...       ...     ...      ...      ...    ...       ...
# 2572  1.0      0.00    0.00      0.0      0.0    NaN      0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    NaN  17826.62
# 2574  NaN      0.00    0.00      0.0      0.0    NaN      0.00
# 2575  NaN      0.00    0.00      0.0      0.0    NaN      0.00
# 2576  NaN      0.00    0.00      0.0      0.0    NaN      0.00
#
# [2577 rows x 7 columns]

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido TC              1.00
# Importe      9058.90
# IVA          1031.15
# RET ISR         0.00
# RET IVA         0.00
# Otros            NaN
# TOTAL MX    10374.70
# dtype: float64
# Limite inferior permitido TC             1.00
# Importe    -5435.34
# IVA         -618.69
# RET ISR        0.00
# RET IVA        0.00
# Otros           NaN
# TOTAL MX   -6224.82
# dtype: float64

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#       TC  Importe  IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 1    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 3    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 4    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# ...   ..      ...  ...      ...      ...    ...       ...
# 2572 NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2573 NaN  17310.3  NaN      NaN      NaN    NaN  17826.62
# 2574 NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2575 NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2576 NaN      NaN  NaN      NaN      NaN    NaN       NaN
#
# [2577 rows x 7 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        TC  Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0  5551.38  888.22      0.0      0.0    NaN    6439.6
# 1     1.0  5551.98  888.32      0.0      0.0    NaN    6440.3
# 2     1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 3     1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 4     1.0     0.00    0.00      0.0      0.0    NaN       0.0
# ...   ...      ...     ...      ...      ...    ...       ...
# 2572  1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 2573  1.0      NaN  516.32      0.0      0.0    NaN       NaN
# 2574  NaN     0.00    0.00      0.0      0.0    NaN       0.0
# 2575  NaN     0.00    0.00      0.0      0.0    NaN       0.0
# 2576  NaN     0.00    0.00      0.0      0.0    NaN       0.0
#
# [2577 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# TC           654
# Importe      305
# IVA          303
# RET ISR       71
# RET IVA       70
# Otros       2577
# TOTAL MX     291
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=data3_iqr.copy()
data5_iqr=data5_iqr.fillna(round(data3_iqr.mean(),1))
data5_iqr
# Out:
#        TC  Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0  5551.38  888.22      0.0      0.0    NaN    6439.6
# 1     1.0  5551.98  888.32      0.0      0.0    NaN    6440.3
# 2     1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 3     1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 4     1.0     0.00    0.00      0.0      0.0    NaN       0.0
# ...   ...      ...     ...      ...      ...    ...       ...
# 2572  1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 2573  1.0  1449.20  516.32      0.0      0.0    NaN    1711.5
# 2574  1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 2575  1.0     0.00    0.00      0.0      0.0    NaN       0.0
# 2576  1.0     0.00    0.00      0.0      0.0    NaN       0.0
#
# [2577 rows x 7 columns]

# %%
data5_iqr.to_csv("2022IQR.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("2022IQR.csv")

# %%
data_clean.to_csv("2022DE.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("2022DE.csv")
