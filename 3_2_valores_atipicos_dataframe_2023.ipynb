# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_excel('GastosYcostos20-30.xlsx', sheet_name='2023')
data
# Out:
#          Fecha       Folio                                  UUID  \
# 0   2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1   2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2   2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3   2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4   2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..         ...         ...                                   ...
# 392 2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393 2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394 2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395 2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396 2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          Proveedor  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 1    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 2    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 3    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 4    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ..            ...                                                ...
# 392  BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 393  BPU7901018D4                                BEBIDAS PURIFICADAS
# 394  BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 395  EFE8908015L3                      EFECTIVALE S. de R.L. de C.V.
# 396  AAE6411055P8                          AESA ARTICULOS ELECTRICOS
#
#                    TIPO GASTO  \
# 0                     COMPRAS
# 1                     COMPRAS
# 2    ARRENDAMIENTO FINANCIERO
# 3    ARRENDAMIENTO FINANCIERO
# 4    ARRENDAMIENTO FINANCIERO
# ..                        ...
# 392         COMISION BANCARIA
# 393                 ALIMENTOS
# 394         COMISION BANCARIA
# 395                  GASOLINA
# 396                   COMPRAS
#
#                                            Descripción   MP    FP   TC  \
# 0                                                 Pago  NaN   NaN  1.0
# 1                                                 Pago  NaN   NaN  1.0
# 2    AA RENTA EXIGIBLE CL0000006876 30/36 de 03/12/...  PPD  99.0  1.0
# 3    AA RENTA EXIGIBLE CL0000006877 30/36 de 03/12/...  PPD  99.0  1.0
# 4    AA RENTA EXIGIBLE CL0000009486 5/48 de 03/12/2...  PPD  99.0  1.0
# ..                                                 ...  ...   ...  ...
# 392                             COMISIONES E INTERESES  PUE   3.0  1.0
# 393                         Epura 20 Lts Policarbonato  PUE   1.0  1.0
# 394                                SERVICIOS BANCARIOS  PUE   3.0  1.0
# 395  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS  PUE   5.0  1.0
# 396                                               Pago  NaN   NaN  1.0
#
#       Importe      IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo  \
# 0        0.00     0.00      0.0      0.0    NaN      0.00       0.00    P
# 1        0.00     0.00      0.0      0.0    NaN      0.00       0.00    P
# 2     5551.38   888.22      0.0      0.0    NaN   6439.60    6439.60    I
# 3     5551.98   888.32      0.0      0.0    NaN   6440.30    6440.30    I
# 4     8454.37  1352.70      0.0      0.0    NaN   9807.07    9807.07    I
# ..        ...      ...      ...      ...    ...       ...        ...  ...
# 392      0.00     0.00      0.0      0.0    NaN      0.00       0.00    I
# 393    220.00     0.00      0.0      0.0    NaN    220.00     220.00    I
# 394  18071.52   682.40      0.0      0.0    NaN  18753.92   18753.92    I
# 395  14472.32     0.00      0.0      0.0    NaN  14472.32   14472.32    I
# 396      0.00     0.00      0.0      0.0    NaN      0.00       0.00    P
#
#       Status      Poliza
# 0    Vigente         NaN
# 1    Vigente         NaN
# 2    Vigente  PE01-ENE23
# 3    Vigente  PE02-ENE23
# 4    Vigente  PE03-ENE23
# ..       ...         ...
# 392  Vigente         NaN
# 393  Vigente         NaN
# 394  Vigente         NaN
# 395  Vigente         NaN
# 396  Vigente         NaN
#
# [397 rows x 20 columns]

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio           13
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       8
# Descripción      0
# MP              71
# FP              71
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza         115
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#          Fecha       Folio                                  UUID  \
# 0   2023-01-01          31  49536321-60A4-523E-A32F-E8BDF5C2276E
# 1   2023-01-01          38  20FBB63B-D550-512F-9668-EEC6F983CEB7
# 2   2023-01-01      341932  DB8C4388-D4E0-4F0C-A09C-77C773257F44
# 3   2023-01-01      341933  A81A63F5-D5EC-4601-803E-375AF9CC5021
# 4   2023-01-01      342205  DCC10492-DE51-4C87-8430-5676FBF81931
# ..         ...         ...                                   ...
# 392 2023-02-01      882974  3E97C399-6747-4BCA-8436-ED4B0933DF33
# 393 2023-02-01      053560  B7132758-F800-4797-B1D6-CC61AFFEE444
# 394 2023-02-01  1092957089  D1E2DC1E-9FFB-46C6-82E4-B350B83CB6F7
# 395 2023-02-01     1453820  6249FE27-6FA6-4EFB-910E-3CD67A0E29A1
# 396 2023-02-01          18  439A9230-277E-5563-818C-7630B0E8D706
#
#               RFC                                          Proveedor  \
# 0    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 1    AAE6411055P8                          AESA ARTICULOS ELECTRICOS
# 2    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 3    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# 4    BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ..            ...                                                ...
# 392  BIN940223KE0  BANCO INVEX, S.A., INSTITUCION DE BANCA MULTIP...
# 393  BPU7901018D4                                BEBIDAS PURIFICADAS
# 394  BMN930209927  BANCO MERCANTIL DEL NORTE SA INSTITUCION DE BA...
# 395  EFE8908015L3                      EFECTIVALE S. de R.L. de C.V.
# 396  AAE6411055P8                          AESA ARTICULOS ELECTRICOS
#
#                    TIPO GASTO  \
# 0                     COMPRAS
# 1                     COMPRAS
# 2    ARRENDAMIENTO FINANCIERO
# 3    ARRENDAMIENTO FINANCIERO
# 4    ARRENDAMIENTO FINANCIERO
# ..                        ...
# 392         COMISION BANCARIA
# 393                 ALIMENTOS
# 394         COMISION BANCARIA
# 395                  GASOLINA
# 396                   COMPRAS
#
#                                            Descripción   MP    FP   TC  \
# 0                                                 Pago  PPD  99.0  1.0
# 1                                                 Pago  PPD  99.0  1.0
# 2    AA RENTA EXIGIBLE CL0000006876 30/36 de 03/12/...  PPD  99.0  1.0
# 3    AA RENTA EXIGIBLE CL0000006877 30/36 de 03/12/...  PPD  99.0  1.0
# 4    AA RENTA EXIGIBLE CL0000009486 5/48 de 03/12/2...  PPD  99.0  1.0
# ..                                                 ...  ...   ...  ...
# 392                             COMISIONES E INTERESES  PUE   3.0  1.0
# 393                         Epura 20 Lts Policarbonato  PUE   1.0  1.0
# 394                                SERVICIOS BANCARIOS  PUE   3.0  1.0
# 395  CONSUMOS DE COMBUSTIBLE DE MONEDEROS ELECTRONICOS  PUE   5.0  1.0
# 396                                               Pago  NaN   NaN  1.0
#
#       Importe      IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo  \
# 0        0.00     0.00      0.0      0.0    NaN      0.00       0.00    P
# 1        0.00     0.00      0.0      0.0    NaN      0.00       0.00    P
# 2     5551.38   888.22      0.0      0.0    NaN   6439.60    6439.60    I
# 3     5551.98   888.32      0.0      0.0    NaN   6440.30    6440.30    I
# 4     8454.37  1352.70      0.0      0.0    NaN   9807.07    9807.07    I
# ..        ...      ...      ...      ...    ...       ...        ...  ...
# 392      0.00     0.00      0.0      0.0    NaN      0.00       0.00    I
# 393    220.00     0.00      0.0      0.0    NaN    220.00     220.00    I
# 394  18071.52   682.40      0.0      0.0    NaN  18753.92   18753.92    I
# 395  14472.32     0.00      0.0      0.0    NaN  14472.32   14472.32    I
# 396      0.00     0.00      0.0      0.0    NaN      0.00       0.00    P
#
#       Status      Poliza
# 0    Vigente  PE01-ENE23
# 1    Vigente  PE01-ENE23
# 2    Vigente  PE01-ENE23
# 3    Vigente  PE02-ENE23
# 4    Vigente  PE03-ENE23
# ..       ...         ...
# 392  Vigente         NaN
# 393  Vigente         NaN
# 394  Vigente         NaN
# 395  Vigente         NaN
# 396  Vigente         NaN
#
# [397 rows x 20 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Fecha            0
# Folio            0
# UUID             0
# RFC              0
# Proveedor        0
# TIPO GASTO       0
# Descripción      0
# MP               1
# FP               1
# TC               0
# Importe          0
# IVA              0
# RET ISR          0
# RET IVA          0
# Otros          397
# TOTAL MX         0
# TOTAL SAT        0
# Tipo             0
# Status           0
# Poliza           8
# dtype: int64

# %%
data2=data.copy()

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido FP             186.819391
# Fecha                 NaT
# IVA           3761.774707
# Importe      26557.244156
# Otros                 NaN
# RET ISR        931.175004
# RET IVA       1022.471745
# TC               4.957143
# TOTAL MX     29218.464899
# TOTAL SAT    29218.464899
# dtype: object
# Limite inferior permitido FP             -98.819391
# Fecha                 NaT
# IVA          -2766.954304
# Importe     -18708.366775
# Otros                 NaN
# RET ISR       -869.142712
# RET IVA       -947.124289
# TC               -2.77403
# TOTAL MX    -20512.146863
# TOTAL SAT   -20512.146863
# dtype: object
# <ipython-input-8-4c899ed993c2>:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-8-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-8-4c899ed993c2>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-8-4c899ed993c2>:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-8-4c899ed993c2>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-8-4c899ed993c2>:4: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()

# %%
#Encontramos Ouliers del Dataframe
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-9-b3686d19c4d6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
#     Fecha Folio UUID  RFC Proveedor TIPO GASTO Descripción   MP  FP  TC  \
# 0     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 1     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 2     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 3     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 4     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# ..    ...   ...  ...  ...       ...        ...         ...  ...  ..  ..
# 392   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 393   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 394   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 395   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
# 396   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN NaN NaN
#
#      Importe  IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo Status  \
# 0        NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 1        NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 2        NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 3        NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 4        NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# ..       ...  ...      ...      ...    ...       ...        ...  ...    ...
# 392      NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 393      NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 394      NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 395      NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
# 396      NaN  NaN      NaN      NaN    NaN       NaN        NaN  NaN    NaN
#
#     Poliza
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 392    NaN
# 393    NaN
# 394    NaN
# 395    NaN
# 396    NaN
#
# [397 rows x 20 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
# <ipython-input-10-1e038dbc0c4a>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data3= data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#     Fecha Folio UUID  RFC Proveedor TIPO GASTO Descripción   MP    FP   TC  \
# 0     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN   NaN  1.0
# 1     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN   NaN  1.0
# 2     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  99.0  1.0
# 3     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  99.0  1.0
# 4     NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN  99.0  1.0
# ..    ...   ...  ...  ...       ...        ...         ...  ...   ...  ...
# 392   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN   3.0  1.0
# 393   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN   1.0  1.0
# 394   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN   3.0  1.0
# 395   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN   5.0  1.0
# 396   NaT   NaN  NaN  NaN       NaN        NaN         NaN  NaN   NaN  1.0
#
#       Importe      IVA  RET ISR  RET IVA  Otros  TOTAL MX  TOTAL SAT Tipo  \
# 0        0.00     0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 1        0.00     0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 2     5551.38   888.22      0.0      0.0    NaN   6439.60    6439.60  NaN
# 3     5551.98   888.32      0.0      0.0    NaN   6440.30    6440.30  NaN
# 4     8454.37  1352.70      0.0      0.0    NaN   9807.07    9807.07  NaN
# ..        ...      ...      ...      ...    ...       ...        ...  ...
# 392      0.00     0.00      0.0      0.0    NaN      0.00       0.00  NaN
# 393    220.00     0.00      0.0      0.0    NaN    220.00     220.00  NaN
# 394  18071.52   682.40      0.0      0.0    NaN  18753.92   18753.92  NaN
# 395  14472.32     0.00      0.0      0.0    NaN  14472.32   14472.32  NaN
# 396      0.00     0.00      0.0      0.0    NaN      0.00       0.00  NaN
#
#     Status Poliza
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 392    NaN    NaN
# 393    NaN    NaN
# 394    NaN    NaN
# 395    NaN    NaN
# 396    NaN    NaN
#
# [397 rows x 20 columns]

# %%
#Eliminamos columnas innecesarias

data4=data3.iloc[ : , 8:15]  
data4
# Out:
#        FP   TC   Importe      IVA  RET ISR  RET IVA  Otros
# 0     NaN  1.0      0.00     0.00      0.0      0.0    NaN
# 1     NaN  1.0      0.00     0.00      0.0      0.0    NaN
# 2    99.0  1.0   5551.38   888.22      0.0      0.0    NaN
# 3    99.0  1.0   5551.98   888.32      0.0      0.0    NaN
# 4    99.0  1.0   8454.37  1352.70      0.0      0.0    NaN
# ..    ...  ...       ...      ...      ...      ...    ...
# 392   3.0  1.0      0.00     0.00      0.0      0.0    NaN
# 393   1.0  1.0    220.00     0.00      0.0      0.0    NaN
# 394   3.0  1.0  18071.52   682.40      0.0      0.0    NaN
# 395   5.0  1.0  14472.32     0.00      0.0      0.0    NaN
# 396   NaN  1.0      0.00     0.00      0.0      0.0    NaN
#
# [397 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data4.isnull().sum()
valores_nulos
# Out:
# FP          71
# TC           2
# Importe     13
# IVA         13
# RET ISR      4
# RET IVA      6
# Otros      397
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data4.copy()
data_clean=data_clean.fillna(round(data4.mean(),1))
data_clean
# Out:
#        FP   TC   Importe      IVA  RET ISR  RET IVA  Otros
# 0    44.0  1.0      0.00     0.00      0.0      0.0    NaN
# 1    44.0  1.0      0.00     0.00      0.0      0.0    NaN
# 2    99.0  1.0   5551.38   888.22      0.0      0.0    NaN
# 3    99.0  1.0   5551.98   888.32      0.0      0.0    NaN
# 4    99.0  1.0   8454.37  1352.70      0.0      0.0    NaN
# ..    ...  ...       ...      ...      ...      ...    ...
# 392   3.0  1.0      0.00     0.00      0.0      0.0    NaN
# 393   1.0  1.0    220.00     0.00      0.0      0.0    NaN
# 394   3.0  1.0  18071.52   682.40      0.0      0.0    NaN
# 395   5.0  1.0  14472.32     0.00      0.0      0.0    NaN
# 396  44.0  1.0      0.00     0.00      0.0      0.0    NaN
#
# [397 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# FP           0
# TC           0
# Importe      0
# IVA          0
# RET ISR      0
# RET IVA      0
# Otros      397
# dtype: int64

# %%
data2= data.iloc[ : , 8:15]
data2
# Out:
#        FP   TC   Importe      IVA  RET ISR  RET IVA  Otros
# 0     NaN  1.0      0.00     0.00      0.0      0.0    NaN
# 1     NaN  1.0      0.00     0.00      0.0      0.0    NaN
# 2    99.0  1.0   5551.38   888.22      0.0      0.0    NaN
# 3    99.0  1.0   5551.98   888.32      0.0      0.0    NaN
# 4    99.0  1.0   8454.37  1352.70      0.0      0.0    NaN
# ..    ...  ...       ...      ...      ...      ...    ...
# 392   3.0  1.0      0.00     0.00      0.0      0.0    NaN
# 393   1.0  1.0    220.00     0.00      0.0      0.0    NaN
# 394   3.0  1.0  18071.52   682.40      0.0      0.0    NaN
# 395   5.0  1.0  14472.32     0.00      0.0      0.0    NaN
# 396   NaN  1.0      0.00     0.00      0.0      0.0    NaN
#
# [397 rows x 7 columns]

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido FP          243.00
# TC            1.00
# Importe    9075.43
# IVA        1120.00
# RET ISR       0.00
# RET IVA       0.00
# Otros          NaN
# dtype: float64
# Limite inferior permitido FP         -141.00
# TC            1.00
# Importe   -5259.05
# IVA        -672.00
# RET ISR       0.00
# RET IVA       0.00
# Otros          NaN
# dtype: float64

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#      FP  TC   Importe     IVA  RET ISR  RET IVA  Otros
# 0   NaN NaN       NaN     NaN      NaN      NaN    NaN
# 1   NaN NaN       NaN     NaN      NaN      NaN    NaN
# 2   NaN NaN       NaN     NaN      NaN      NaN    NaN
# 3   NaN NaN       NaN     NaN      NaN      NaN    NaN
# 4   NaN NaN       NaN  1352.7      NaN      NaN    NaN
# ..   ..  ..       ...     ...      ...      ...    ...
# 392 NaN NaN       NaN     NaN      NaN      NaN    NaN
# 393 NaN NaN       NaN     NaN      NaN      NaN    NaN
# 394 NaN NaN  18071.52     NaN      NaN      NaN    NaN
# 395 NaN NaN  14472.32     NaN      NaN      NaN    NaN
# 396 NaN NaN       NaN     NaN      NaN      NaN    NaN
#
# [397 rows x 7 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        FP   TC  Importe     IVA  RET ISR  RET IVA  Otros
# 0     NaN  1.0     0.00    0.00      0.0      0.0    NaN
# 1     NaN  1.0     0.00    0.00      0.0      0.0    NaN
# 2    99.0  1.0  5551.38  888.22      0.0      0.0    NaN
# 3    99.0  1.0  5551.98  888.32      0.0      0.0    NaN
# 4    99.0  1.0  8454.37     NaN      0.0      0.0    NaN
# ..    ...  ...      ...     ...      ...      ...    ...
# 392   3.0  1.0     0.00    0.00      0.0      0.0    NaN
# 393   1.0  1.0   220.00    0.00      0.0      0.0    NaN
# 394   3.0  1.0      NaN  682.40      0.0      0.0    NaN
# 395   5.0  1.0      NaN    0.00      0.0      0.0    NaN
# 396   NaN  1.0     0.00    0.00      0.0      0.0    NaN
#
# [397 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# FP          71
# TC           2
# Importe     50
# IVA         49
# RET ISR      9
# RET IVA      9
# Otros      397
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=data3_iqr.copy()
data5_iqr=data5_iqr.fillna(round(data3_iqr.mean(),1))
data5_iqr
# Out:
#        FP   TC  Importe     IVA  RET ISR  RET IVA  Otros
# 0    44.0  1.0     0.00    0.00      0.0      0.0    NaN
# 1    44.0  1.0     0.00    0.00      0.0      0.0    NaN
# 2    99.0  1.0  5551.38  888.22      0.0      0.0    NaN
# 3    99.0  1.0  5551.98  888.32      0.0      0.0    NaN
# 4    99.0  1.0  8454.37  176.80      0.0      0.0    NaN
# ..    ...  ...      ...     ...      ...      ...    ...
# 392   3.0  1.0     0.00    0.00      0.0      0.0    NaN
# 393   1.0  1.0   220.00    0.00      0.0      0.0    NaN
# 394   3.0  1.0  1521.50  682.40      0.0      0.0    NaN
# 395   5.0  1.0  1521.50    0.00      0.0      0.0    NaN
# 396  44.0  1.0     0.00    0.00      0.0      0.0    NaN
#
# [397 rows x 7 columns]

# %%
data5_iqr.to_csv("2023IQR.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("2023IQR.csv")

# %%
data_clean.to_csv("2023DE.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("2023DE.csv")
